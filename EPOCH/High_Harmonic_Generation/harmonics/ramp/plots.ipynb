# %%
import numpy as np
import matplotlib.pyplot as plt
import sdf
import os, glob

# %%
from plot import *

# %%
data_dir = "run3"
fig_dir = "images"
plot_density = True
plot_ffts = True
plot_fields2d = True
plot_fields_with_time = True
show_figs = False
save_figs = True

main(
    data_dir=data_dir,
    save_figs=save_figs,
    show_figs=show_figs,
    plot_density=plot_density,
    plot_ffts=plot_ffts,
    plot_fields2d=plot_fields2d,
    plot_fields_with_time=plot_fields_with_time,
    fig_dir=fig_dir,
)
# Out:
# Values from input.deck:
# lambda0 =  1e-06
# laser_time =  20
# t_end =  40
# dt_snapshot =  8e-17
# a0 =  4.0
# factor =  4
# nx =  16000
# x_min =  -20
# Calculated Values for the simulation are:
# omega0 =  1883651567308853.2
# tau =  3.3356409519815205e-15
# nc =  1.1143269197457677e+27
# Er =  3210701072782.3525
# n0 =  4.457307678983071e+27
# LAS_TIME =  6.671281903963041e-14
# f_max =  1.25e+16
# omega_max =  41.69551189976901
# Getting Data...: 100%|██████████| 1669/1669 [00:05<00:00, 278.66it/s]
