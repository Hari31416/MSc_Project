# %%
import sdf_helper as sh
import matplotlib.pyplot as plt
import os
import sdf

# %%
data = sh.getdata('0010.sdf')
# Out:
# Reading file 0010.sdf
# t() = time
# bx(500, 200) = bx
# by(500, 200) = by
# bz(500, 200) = bz
# ex(500, 200) = ex
# ey(500, 200) = ey
# ez(500, 200) = ez
# x(501, 201) = grid
# y(501, 201) = grid
# xc(500, 200) = grid_mid
# yc(500, 200) = grid_mid

# %%
def plot_field(data, ax, t):
    data = sdf.read(data)
    variable = data.Electric_Field_Ey.data
    ax.imshow(variable**2, cmap='gray', origin='lower',
    extent=[-10,10, -25, 25],
    aspect='auto')
    ax.set_xlabel('$y \, [\mu m]$')
    ax.set_ylabel('$x \, [\mu m]$')
    ax.set_title(f't = {t} fs')

# %%
all_files = [f for f in os.listdir('.') if f.endswith('.sdf')]

# %%
fig, ax = plt.subplots(3, 5, figsize=(25, 18))
i=0
for data in all_files[:-1]:
    t = i*10
    plot_field(data, ax[i // 5, i % 5], t)
    i += 1

# %%
data=sh.getdata('0013.sdf')
sh.plot_auto(data.Electric_Field_Ey)

# %%
data.Electric_Field_Ex.data.max()
# Out:
# 223532800128.7786

# %%
dir(data.Electric_Field_Ex)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'blocklist',
#  'data',
#  'data_length',
#  'datatype',
#  'dims',
#  'grid',
#  'grid_id',
#  'grid_mid',
#  'id',
#  'mult',
#  'name',
#  'stagger',
#  'units']

# %%
sh.plot_auto(data.Electric_Field_Ex, iso=0)

# %%
import sdf

# %%
data = sdf.read('0010.sdf')

# %%
data.Electric_Field_Ex.data
# Out:
# array([[-3.42265113e+12, -1.56343279e+12, -3.40040534e+11, ...,
#          2.87512379e+11, -3.57195203e+11, -1.57201134e+12],
#        [-1.74551857e+12, -1.11281007e+12, -3.10094038e+11, ...,
#          2.78478372e+11, -3.04814421e+11, -1.11012472e+12],
#        [-6.57061156e+11, -3.99384121e+11,  6.23674730e+10, ...,
#          4.83590104e+11,  8.82321435e+10, -3.86376218e+11],
#        ...,
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
data.Electric_Field_Ex.units
# Out:
# 'V/m'

# %%
data=sdf.read('0005.sdf')
ey = data.Electric_Field_Ey
plt.pcolormesh(ey.grid_mid.data[0], ey.grid_mid.data[1], ey.data.T)
plt.show()

# %%
ey.grid_mid.data[0].shape, ey.grid_mid.data[1].shape
# Out:
# ((500,), (200,))

# %%
plt.imshow(variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /media/hari31416/Hari_SSD/Users/harik/Desktop/Project_Sem_3/epoch/6.1.1/temp.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/media/hari31416/Hari_SSD/Users/harik/Desktop/Project_Sem_3/epoch/6.1.1/temp.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> plt.imshow(variable)
#
# NameError: name 'variable' is not defined
